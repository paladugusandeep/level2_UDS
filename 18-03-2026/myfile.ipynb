# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
uri=f"mongodb+srv://spaladu:Sandy12345678@cluster0.rlsyv34.mongodb.net/?appName=Cluster0"

# %%
client = MongoClient(uri, server_api=ServerApi('1'))

# %%
try :
    client.admin.command('ping')
    print("Connection successfull.")
except Exception as e:
    print(e)
# Out:
# Connection successfull.

# %%
client.list_database_names()
# Out:
# ['sample_mflix', 'ultimate-datascience-b2', 'admin', 'local']

# %%
# db = client.ultimate_data_science_b2
db = client["ultimate-datascience-b2"]

# %%
db.list_collection_names()
# Out:
# ['dummy0']

# %%
collection = db.dummy0

# %% [markdown]
# # Select

# %%
for i in collection.find({}):
    print(i)
# Out:
# {'_id': ObjectId('69bce67668d87c48b4596fbf'), 'user_name': 'Sandeep'}
# {'_id': ObjectId('69bd492168d87c48b4596fc1'), 'brand': 'Apple', 'model': 'iPhone 15 Pro', 'storage': ['128GB', '256GB', '512GB', '1TB'], 'color': ['Titanium Black', 'Titanium White', 'Titanium Blue'], 'price': 999, 'releaseDate': '2023-09-22T00:00:00Z', 'specs': {'display': '6.1-inch ProMotion OLED', 'processor': 'A17 Pro', 'camera': '48MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd524221c5afbcd80c19a1'), 'brand': 'Samsung', 'model': 'Galaxy S24 Ultra', 'storage': ['256GB', '512GB', '1TB'], 'color': ['Titanium Gray', 'Titanium Violet'], 'price': 1299.99, 'releaseDate': '2024-01-17T00:00:00Z', 'specs': {'display': '6.8-inch Dynamic AMOLED 2X', 'processor': 'Snapdragon 8 Gen 3', 'camera': '200MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd527221c5afbcd80c19a2'), 'brand': 'Google', 'model': 'Pixel 8', 'storage': ['128GB', '256GB'], 'color': ['Hazel', 'Obsidian', 'Rose'], 'price': 699, 'releaseDate': '2023-10-12T00:00:00Z', 'specs': {'display': '6.2-inch Actua Display', 'processor': 'Google Tensor G3', 'camera': '50MP Wide'}, 'inStock': False, 'category': 'smartphone'}

# %%
document=collection.find_one({})
print(document)
# Out:
# {'_id': ObjectId('69bce67668d87c48b4596fbf'), 'user_name': 'Sandeep'}

# %%
# find all the category which belongs to smartphone
for i in collection.find({"category":"smartphone"}):
    print(i)
# Out:
# {'_id': ObjectId('69bd492168d87c48b4596fc1'), 'brand': 'Apple', 'model': 'iPhone 15 Pro', 'storage': ['128GB', '256GB', '512GB', '1TB'], 'color': ['Titanium Black', 'Titanium White', 'Titanium Blue'], 'price': 999, 'releaseDate': '2023-09-22T00:00:00Z', 'specs': {'display': '6.1-inch ProMotion OLED', 'processor': 'A17 Pro', 'camera': '48MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd524221c5afbcd80c19a1'), 'brand': 'Samsung', 'model': 'Galaxy S24 Ultra', 'storage': ['256GB', '512GB', '1TB'], 'color': ['Titanium Gray', 'Titanium Violet'], 'price': 1299.99, 'releaseDate': '2024-01-17T00:00:00Z', 'specs': {'display': '6.8-inch Dynamic AMOLED 2X', 'processor': 'Snapdragon 8 Gen 3', 'camera': '200MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd527221c5afbcd80c19a2'), 'brand': 'Google', 'model': 'Pixel 8', 'storage': ['128GB', '256GB'], 'color': ['Hazel', 'Obsidian', 'Rose'], 'price': 699, 'releaseDate': '2023-10-12T00:00:00Z', 'specs': {'display': '6.2-inch Actua Display', 'processor': 'Google Tensor G3', 'camera': '50MP Wide'}, 'inStock': False, 'category': 'smartphone'}

# %%
# find all the rows which has category key in it
query={
    "category": {"$exists":True}
}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('69bd492168d87c48b4596fc1'), 'brand': 'Apple', 'model': 'iPhone 15 Pro', 'storage': ['128GB', '256GB', '512GB', '1TB'], 'color': ['Titanium Black', 'Titanium White', 'Titanium Blue'], 'price': 999, 'releaseDate': '2023-09-22T00:00:00Z', 'specs': {'display': '6.1-inch ProMotion OLED', 'processor': 'A17 Pro', 'camera': '48MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd524221c5afbcd80c19a1'), 'brand': 'Samsung', 'model': 'Galaxy S24 Ultra', 'storage': ['256GB', '512GB', '1TB'], 'color': ['Titanium Gray', 'Titanium Violet'], 'price': 1299.99, 'releaseDate': '2024-01-17T00:00:00Z', 'specs': {'display': '6.8-inch Dynamic AMOLED 2X', 'processor': 'Snapdragon 8 Gen 3', 'camera': '200MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd527221c5afbcd80c19a2'), 'brand': 'Google', 'model': 'Pixel 8', 'storage': ['128GB', '256GB'], 'color': ['Hazel', 'Obsidian', 'Rose'], 'price': 699, 'releaseDate': '2023-10-12T00:00:00Z', 'specs': {'display': '6.2-inch Actua Display', 'processor': 'Google Tensor G3', 'camera': '50MP Wide'}, 'inStock': False, 'category': 'smartphone'}

# %%
# get all the smartphone category where price is greater than 0
query={
    "category":"smartphone",
    "price":{"$gt":0}
}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('69bd492168d87c48b4596fc1'), 'brand': 'Apple', 'model': 'iPhone 15 Pro', 'storage': ['128GB', '256GB', '512GB', '1TB'], 'color': ['Titanium Black', 'Titanium White', 'Titanium Blue'], 'price': 999, 'releaseDate': '2023-09-22T00:00:00Z', 'specs': {'display': '6.1-inch ProMotion OLED', 'processor': 'A17 Pro', 'camera': '48MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd524221c5afbcd80c19a1'), 'brand': 'Samsung', 'model': 'Galaxy S24 Ultra', 'storage': ['256GB', '512GB', '1TB'], 'color': ['Titanium Gray', 'Titanium Violet'], 'price': 1299.99, 'releaseDate': '2024-01-17T00:00:00Z', 'specs': {'display': '6.8-inch Dynamic AMOLED 2X', 'processor': 'Snapdragon 8 Gen 3', 'camera': '200MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd527221c5afbcd80c19a2'), 'brand': 'Google', 'model': 'Pixel 8', 'storage': ['128GB', '256GB'], 'color': ['Hazel', 'Obsidian', 'Rose'], 'price': 699, 'releaseDate': '2023-10-12T00:00:00Z', 'specs': {'display': '6.2-inch Actua Display', 'processor': 'Google Tensor G3', 'camera': '50MP Wide'}, 'inStock': False, 'category': 'smartphone'}

# %%
for i in collection.find({
    "category":"smartphone",
    "price":{"$gt":0}
}):
    print(i)
# Out:
# {'_id': ObjectId('69bd492168d87c48b4596fc1'), 'brand': 'Apple', 'model': 'iPhone 15 Pro', 'storage': ['128GB', '256GB', '512GB', '1TB'], 'color': ['Titanium Black', 'Titanium White', 'Titanium Blue'], 'price': 999, 'releaseDate': '2023-09-22T00:00:00Z', 'specs': {'display': '6.1-inch ProMotion OLED', 'processor': 'A17 Pro', 'camera': '48MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd524221c5afbcd80c19a1'), 'brand': 'Samsung', 'model': 'Galaxy S24 Ultra', 'storage': ['256GB', '512GB', '1TB'], 'color': ['Titanium Gray', 'Titanium Violet'], 'price': 1299.99, 'releaseDate': '2024-01-17T00:00:00Z', 'specs': {'display': '6.8-inch Dynamic AMOLED 2X', 'processor': 'Snapdragon 8 Gen 3', 'camera': '200MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd527221c5afbcd80c19a2'), 'brand': 'Google', 'model': 'Pixel 8', 'storage': ['128GB', '256GB'], 'color': ['Hazel', 'Obsidian', 'Rose'], 'price': 699, 'releaseDate': '2023-10-12T00:00:00Z', 'specs': {'display': '6.2-inch Actua Display', 'processor': 'Google Tensor G3', 'camera': '50MP Wide'}, 'inStock': False, 'category': 'smartphone'}

# %% [markdown]
# # Insert

# %%
new_product = {'name': 'iphone 17 pro', 
'category': 'smartphone', 
'price': 1600.0, 
'features': ['3-camera', 'display-retina'],
'manufacturer': {
    'name': 'foxconn tech', 
    'country': 'china'}
}
result = collection.insert_one(new_product)
print(f"Inserted document ID : {result.inserted_id}")
# Out:
# Inserted document ID : 69bd59d3033ceec1438f2a5e

# %%
result =collection.insert_one({'name': 'iphone 18 pro', 
'category': 'smartphone', 
'price': 2000.0, 
'features': ['3-camera', 'display-retina'],
'manufacturer': {
    'name': 'foxconn tech', 
    'country': 'china'}
})
print(f"Inserted document ID : {result.inserted_id}")
# Out:
# Inserted document ID : 69bd5a11033ceec1438f2a5f

# %%
collection = db.dummy0
for i in collection.find({}):
    print(i)
# Out:
# {'_id': ObjectId('69bd492168d87c48b4596fc1'), 'brand': 'Apple', 'model': 'iPhone 15 Pro', 'storage': ['128GB', '256GB', '512GB', '1TB'], 'color': ['Titanium Black', 'Titanium White', 'Titanium Blue'], 'price': 999, 'releaseDate': '2023-09-22T00:00:00Z', 'specs': {'display': '6.1-inch ProMotion OLED', 'processor': 'A17 Pro', 'camera': '48MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd524221c5afbcd80c19a1'), 'brand': 'Samsung', 'model': 'Galaxy S24 Ultra', 'storage': ['256GB', '512GB', '1TB'], 'color': ['Titanium Gray', 'Titanium Violet'], 'price': 1299.99, 'releaseDate': '2024-01-17T00:00:00Z', 'specs': {'display': '6.8-inch Dynamic AMOLED 2X', 'processor': 'Snapdragon 8 Gen 3', 'camera': '200MP Main'}, 'inStock': True, 'category': 'smartphone'}
# {'_id': ObjectId('69bd527221c5afbcd80c19a2'), 'brand': 'Google', 'model': 'Pixel 8', 'storage': ['128GB', '256GB'], 'color': ['Hazel', 'Obsidian', 'Rose'], 'price': 699, 'releaseDate': '2023-10-12T00:00:00Z', 'specs': {'display': '6.2-inch Actua Display', 'processor': 'Google Tensor G3', 'camera': '50MP Wide'}, 'inStock': False, 'category': 'smartphone'}
# {'_id': ObjectId('69bd59d3033ceec1438f2a5e'), 'name': 'iphone 17 pro', 'category': 'smartphone_latest', 'price': 1600.0, 'features': ['3-camera', 'display-retina'], 'manufacturer': {'name': 'foxconn tech', 'country': 'china'}}
# {'_id': ObjectId('69bd5a11033ceec1438f2a5f'), 'name': 'iphone 18 pro', 'category': 'smartphone', 'price': 2000.0, 'features': ['3-camera', 'display-retina'], 'manufacturer': {'name': 'foxconn tech', 'country': 'china'}}

# %%
result=collection.delete_many({
    "user_name":"Sandeep"
})
print(f"Record deleted: {result.deleted_count}")
# Out:
# Record deleted: 1

# %%
for i in collection.find({
     "model" : {"$regex" : "pixel", "$options" : "i"}
}):
    print(i)
# Out:
# {'_id': ObjectId('69bd527221c5afbcd80c19a2'), 'brand': 'Google', 'model': 'Pixel 8', 'storage': ['128GB', '256GB'], 'color': ['Hazel', 'Obsidian', 'Rose'], 'price': 699, 'releaseDate': '2023-10-12T00:00:00Z', 'specs': {'display': '6.2-inch Actua Display', 'processor': 'Google Tensor G3', 'camera': '50MP Wide'}, 'inStock': False, 'category': 'smartphone'}

# %%
query_filter = {
    "name" : {"$regex" : "17", "$options" : "i"}
}

update_operation = {
    "$set" : {
        "category" : "smartphone_latest"
    }
}

result = collection.update_many(query_filter, update_operation)

print(f"Matched {result.matched_count} documents and modified {result.modified_count} documents.")
# Out:
# Matched 1 documents and modified 1 documents.

# %%
query_filter = {
    "name": {"$regex": "17", "$options": "i"}
}

update_operation = {
    "$set": {
        "category": "smartphone_latest"
    }
}

result = collection.update_many(query_filter, update_operation)

print(f"Matched {result.matched_count} documents and modified {result.modified_count} documents.")
# Out:
# Matched 1 documents and modified 0 documents.
