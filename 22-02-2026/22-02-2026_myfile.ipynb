# %% [markdown]
# ## Creating a dataframe

# %%
import pandas as pd

# %%
data={
    "Name":['Sandeep','Padmini','Shannu'],
    "Age":['39','37','6'],
    "City":['GDK','HYT','HYD']
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#       Name Age City
# 0  Sandeep  39  GDK
# 1  Padmini  37  HYT
# 2   Shannu   6  HYD

# %%
df
# Out:
#       Name Age City
# 0  Sandeep  39  GDK
# 1  Padmini  37  HYT
# 2   Shannu   6  HYD
